# %% [markdown]
# <a href="https://colab.research.google.com/github/ShahinGanbar/QSS_tasks/blob/main/Week3_CS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
file_path = '/content/drive/MyDrive/train (1).csv'

# %%
import pandas as pd

# %%
data = pd.read_csv(file_path)

# %%
data.head()
# Out:
#    ID_code  target    var_0   var_1    var_2   var_3    var_4   var_5   var_6  \
# 0  train_0       0   8.9255 -6.7863  11.9081  5.0930  11.4607 -9.2834  5.1187
# 1  train_1       0  11.5006 -4.1473  13.8588  5.3890  12.3622  7.0433  5.6208
# 2  train_2       0   8.6093 -2.7457  12.0805  7.8928  10.5825 -9.0837  6.9427
# 3  train_3       0  11.0604 -2.1518   8.9522  7.1957  12.5846 -1.8361  5.8428
# 4  train_4       0   9.8369 -1.4834  12.8746  6.6375  12.2772  2.4486  5.9405
#
#      var_7  ...  var_190  var_191  var_192  var_193  var_194  var_195  \
# 0  18.6266  ...   4.4354   3.9642   3.1364   1.6910  18.5227  -2.3978
# 1  16.5338  ...   7.6421   7.7214   2.5837  10.9516  15.4305   2.0339
# 2  14.6155  ...   2.9057   9.7905   1.6704   1.6858  21.6042   3.1417
# 3  14.9250  ...   4.4666   4.7433   0.7178   1.4214  23.0347  -1.2706
# 4  19.2514  ...  -1.4905   9.5214  -0.1508   9.1942  13.2876  -1.5121
#
#    var_196  var_197  var_198  var_199
# ...

# %%
#1

df = pd.DataFrame(data)
df.head(7)
# Out:
#    ID_code  target    var_0   var_1    var_2   var_3    var_4   var_5   var_6  \
# 0  train_0       0   8.9255 -6.7863  11.9081  5.0930  11.4607 -9.2834  5.1187
# 1  train_1       0  11.5006 -4.1473  13.8588  5.3890  12.3622  7.0433  5.6208
# 2  train_2       0   8.6093 -2.7457  12.0805  7.8928  10.5825 -9.0837  6.9427
# 3  train_3       0  11.0604 -2.1518   8.9522  7.1957  12.5846 -1.8361  5.8428
# 4  train_4       0   9.8369 -1.4834  12.8746  6.6375  12.2772  2.4486  5.9405
# 5  train_5       0  11.4763 -2.3182  12.6080  8.6264  10.9621  3.5609  4.5322
# 6  train_6       0  11.8091 -0.0832   9.3494  4.2916  11.1355 -8.0198  6.1961
#
#      var_7  ...  var_190  var_191  var_192  var_193  var_194  var_195  \
# 0  18.6266  ...   4.4354   3.9642   3.1364   1.6910  18.5227  -2.3978
# 1  16.5338  ...   7.6421   7.7214   2.5837  10.9516  15.4305   2.0339
# 2  14.6155  ...   2.9057   9.7905   1.6704   1.6858  21.6042   3.1417
# ...

# %%
#2

df.isnull().any().any()
# Out:
# np.False_

# %%
#3

df.groupby('target').mean(numeric_only=True)
# Out:
#             var_0     var_1      var_2     var_3      var_4     var_5  \
# target
# 0       10.626681 -1.695770  10.665876  6.788979  11.072412 -5.146736
# 1       11.156418 -1.017613  11.156633  6.864113  11.131337 -4.336522
#
#            var_6      var_7     var_8     var_9  ...   var_190  var_191  \
# target                                           ...
# 0       5.389620  16.549306  0.262347  7.584907  ...  3.149130  7.39080
# 1       5.581966  16.514917  0.479432  7.409064  ...  3.998064  7.86456
#
#          var_192   var_193    var_194   var_195   var_196   var_197  \
# target
# 0       1.949017  3.355403  18.017716 -0.155601  2.260297  8.919032
# 1       1.738266  3.120260  17.779568 -0.021130  2.688583  8.810815
#
#           var_198   var_199
# target
# 0       15.924058 -3.415273
# 1       15.393283 -2.532243
#
# [2 rows x 200 columns]

# %%
#4
df['target'].value_counts()
# Out:
# target
# 0    179902
# 1     20098
# Name: count, dtype: int64

# %%
#5

df.drop(columns=['ID_code'],inplace=True)

# %%
#6 a)
df.describe()
# Out:
#               target          var_0          var_1          var_2  \
# count  200000.000000  200000.000000  200000.000000  200000.000000
# mean        0.100490      10.679914      -1.627622      10.715192
# std         0.300653       3.040051       4.050044       2.640894
# min         0.000000       0.408400     -15.043400       2.117100
# 25%         0.000000       8.453850      -4.740025       8.722475
# 50%         0.000000      10.524750      -1.608050      10.580000
# 75%         0.000000      12.758200       1.358625      12.516700
# max         1.000000      20.315000      10.376800      19.353000
#
#                var_3          var_4          var_5          var_6  \
# count  200000.000000  200000.000000  200000.000000  200000.000000
# mean        6.796529      11.078333      -5.065317       5.408949
# std         2.043319       1.623150       7.863267       0.866607
# min        -0.040200       5.074800     -32.562600       2.347300
# ...

# %%
#6 b)

print(df['var_0'].mean())
# Out:
# 10.679914251999998

# %%
#7
# print(df.var_0.min())
# print(df.var_0.mean())
filtered = df[(df.var_0 >= df.var_0.min()) & (df.var_0 <= df.var_0.mean())]
print(filtered)
# Out:
#         target   var_0   var_1    var_2   var_3    var_4    var_5   var_6  \
# 0            0  8.9255 -6.7863  11.9081  5.0930  11.4607  -9.2834  5.1187
# 2            0  8.6093 -2.7457  12.0805  7.8928  10.5825  -9.0837  6.9427
# 4            0  9.8369 -1.4834  12.8746  6.6375  12.2772   2.4486  5.9405
# 10           0  5.0702 -0.5447   9.5900  4.2987  12.3910 -18.8687  6.0382
# 12           0  8.7671 -4.6154   9.7242  7.4242   9.0254   1.4247  6.2815
# ...        ...     ...     ...      ...     ...      ...      ...     ...
# 199985       0  9.0249 -3.6379  12.3907  5.1915  12.1701  -8.8978  5.2574
# 199987       0  8.0438 -1.9184  13.1498  9.2027   8.9886   2.7531  4.2194
# 199991       0  9.9909  2.5523  11.9653  6.3958  13.5497  -9.5293  6.0864
# 199996       0  4.9149 -2.4484  16.7052  6.6345   8.3096 -10.5628  5.8802
# 199998       0  9.7148 -8.6098  13.6104  5.7930  12.5173   0.5339  6.0479
#
#           var_7   var_8  ...  var_190  var_191  var_192  var_193  var_194  \
# ...

# %%
#8

filtered_2 = df[(df.var_6 > 5) & (df.var_196 < 2)]
print(filtered)
# Out:
#         target   var_0   var_1    var_2   var_3    var_4    var_5   var_6  \
# 0            0  8.9255 -6.7863  11.9081  5.0930  11.4607  -9.2834  5.1187
# 2            0  8.6093 -2.7457  12.0805  7.8928  10.5825  -9.0837  6.9427
# 4            0  9.8369 -1.4834  12.8746  6.6375  12.2772   2.4486  5.9405
# 10           0  5.0702 -0.5447   9.5900  4.2987  12.3910 -18.8687  6.0382
# 12           0  8.7671 -4.6154   9.7242  7.4242   9.0254   1.4247  6.2815
# ...        ...     ...     ...      ...     ...      ...      ...     ...
# 199985       0  9.0249 -3.6379  12.3907  5.1915  12.1701  -8.8978  5.2574
# 199987       0  8.0438 -1.9184  13.1498  9.2027   8.9886   2.7531  4.2194
# 199991       0  9.9909  2.5523  11.9653  6.3958  13.5497  -9.5293  6.0864
# 199996       0  4.9149 -2.4484  16.7052  6.6345   8.3096 -10.5628  5.8802
# 199998       0  9.7148 -8.6098  13.6104  5.7930  12.5173   0.5339  6.0479
#
#           var_7   var_8  ...  var_190  var_191  var_192  var_193  var_194  \
# ...

# %%
#9

col = df.iloc[20000:30000,10]
print(col)
# Out:
# 20000    6.2325
# 20001    5.4199
# 20002    8.5767
# 20003    6.0312
# 20004    6.8624
#           ...
# 29995    9.0503
# 29996    5.9313
# 29997    8.9955
# 29998    7.6509
# 29999    6.4558
# Name: var_9, Length: 10000, dtype: float64

# %%
#10 a)

features = [f"var_{i}" for i in range(10)]
features_df = df[features]
corr_matrix = features_df.corr()
print(corr_matrix)
# Out:
#           var_0     var_1     var_2     var_3     var_4     var_5     var_6  \
# var_0  1.000000 -0.000544  0.006573  0.003801  0.001326  0.003046  0.006983
# var_1 -0.000544  1.000000  0.003980  0.000010  0.000303 -0.000902  0.003258
# var_2  0.006573  0.003980  1.000000  0.001001  0.000723  0.001569  0.000883
# var_3  0.003801  0.000010  0.001001  1.000000 -0.000322  0.003253 -0.000774
# var_4  0.001326  0.000303  0.000723 -0.000322  1.000000 -0.001368  0.000049
# var_5  0.003046 -0.000902  0.001569  0.003253 -0.001368  1.000000  0.002588
# var_6  0.006983  0.003258  0.000883 -0.000774  0.000049  0.002588  1.000000
# var_7  0.002429  0.001511 -0.000991  0.002500  0.004549 -0.000995 -0.002548
# var_8  0.004962  0.004098  0.002648  0.003553  0.001194  0.000147 -0.001188
# var_9 -0.002613 -0.000832 -0.001932 -0.000826 -0.000918 -0.005279 -0.005697
#
#           var_7     var_8     var_9
# var_0  0.002429  0.004962 -0.002613
# var_1  0.001511  0.004098 -0.000832
# ...

# %%
# b)

import numpy as np

df2 = corr_matrix.replace(1,np.nan)
print(df2)
# Out:
#           var_0     var_1     var_2     var_3     var_4     var_5     var_6  \
# var_0       NaN -0.000544  0.006573  0.003801  0.001326  0.003046  0.006983
# var_1 -0.000544       NaN  0.003980  0.000010  0.000303 -0.000902  0.003258
# var_2  0.006573  0.003980       NaN  0.001001  0.000723  0.001569  0.000883
# var_3  0.003801  0.000010  0.001001       NaN -0.000322  0.003253 -0.000774
# var_4  0.001326  0.000303  0.000723 -0.000322       NaN -0.001368  0.000049
# var_5  0.003046 -0.000902  0.001569  0.003253 -0.001368       NaN  0.002588
# var_6  0.006983  0.003258  0.000883 -0.000774  0.000049  0.002588       NaN
# var_7  0.002429  0.001511 -0.000991  0.002500  0.004549 -0.000995 -0.002548
# var_8  0.004962  0.004098  0.002648  0.003553  0.001194  0.000147 -0.001188
# var_9 -0.002613 -0.000832 -0.001932 -0.000826 -0.000918 -0.005279 -0.005697
#
#           var_7     var_8     var_9
# var_0  0.002429  0.004962 -0.002613
# var_1  0.001511  0.004098 -0.000832
# ...

# %%
df2.unstack()
# Out:
# var_0  var_0         NaN
#        var_1   -0.000544
#        var_2    0.006573
#        var_3    0.003801
#        var_4    0.001326
#                   ...
# var_9  var_5   -0.005279
#        var_6   -0.005697
#        var_7    0.002885
#        var_8   -0.001073
#        var_9         NaN
# Length: 100, dtype: float64

# %%
df2.unstack().reset_index()
# Out:
#    level_0 level_1         0
# 0    var_0   var_0       NaN
# 1    var_0   var_1 -0.000544
# 2    var_0   var_2  0.006573
# 3    var_0   var_3  0.003801
# 4    var_0   var_4  0.001326
# ..     ...     ...       ...
# 95   var_9   var_5 -0.005279
# 96   var_9   var_6 -0.005697
# 97   var_9   var_7  0.002885
# 98   var_9   var_8 -0.001073
# 99   var_9   var_9       NaN
#
# [100 rows x 3 columns]

# %%
df2.unstack().reset_index().dropna()
# Out:
#    level_0 level_1         0
# 1    var_0   var_1 -0.000544
# 2    var_0   var_2  0.006573
# 3    var_0   var_3  0.003801
# 4    var_0   var_4  0.001326
# 5    var_0   var_5  0.003046
# ..     ...     ...       ...
# 94   var_9   var_4 -0.000918
# 95   var_9   var_5 -0.005279
# 96   var_9   var_6 -0.005697
# 97   var_9   var_7  0.002885
# 98   var_9   var_8 -0.001073
#
# [90 rows x 3 columns]

# %%
df3 = df2.unstack().reset_index().dropna().sort_values(by=[0],ascending=False)[0:20:2]
print(df3)
# Out:
#    level_0 level_1         0
# 6    var_0   var_6  0.006983
# 20   var_2   var_0  0.006573
# 80   var_8   var_0  0.004962
# 47   var_4   var_7  0.004549
# 18   var_1   var_8  0.004098
# 12   var_1   var_2  0.003980
# 30   var_3   var_0  0.003801
# 38   var_3   var_8  0.003553
# 16   var_1   var_6  0.003258
# 53   var_5   var_3  0.003253

# %%
#11
import pandas as pd

df_clean = df.drop(columns=["target"],inplace=False)

q1 = df_clean.quantile(0.25)
q3 = df_clean.quantile(0.75)

iqr = q3 - q1

lower_bound = q1-1.5*iqr
upper_bound = q3+1.5*iqr

for col in df_clean.columns:
    cleaned = df_clean[(df_clean[col] > lower_bound[col]) & (df_clean[col] < upper_bound[col])]


cleaned.shape
# Out:
# (199980, 200)
